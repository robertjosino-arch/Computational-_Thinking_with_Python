# %% [markdown]
# estoque = {"Maça": 10, "Banana": 5, "Laranja": 8,}
#
# for fruta, qtd in estoque.items():
#   print(f"{fruta}: {qtd} unidades")
#
# ###################################################################
#
# alunos = {
#
#     "Ana": {"n1": 8, "n2": 7},
#
#     "Bruno": {"n1": 5, "n2": 6}
#
# }
#
# for nome, notas in alunos.items():
#
#     #for prova, valor in notas.items():
#
#         print(nome, notas)
#
# ###################################################################
#
# carrinho = {}
# produto = ""
#
# while produto != "sair":
#    produto = input("Produto: ")
#    if produto == "sair":
#        break
#    preco = float(input("Preço: "))
#    carrinho[produto] = preco
#
# print(carrinho)
#
#
#
# ###################################################################
#
# # EXERCICIO 1
#
# nome = input("Nome: ")
# n1 = float(input("Nota 1: "))
# n2 = float(input("Nota 2: "))
# n3 = float(input("Nota 3: "))
#
# aluno = {"nome": nome, "n1": n1, "n2": n2, "n3": n3}
# media = (aluno["n1"] + aluno["n2"] + aluno["n3"]) / 3
#
# if media >= 6:
#    print("Aprovado")
# else:
#    print("Reprovado")
#
# ###################################################################
#
# # EXERCICIO 2
#
# conta = {"titular": "João", "saldo": 500}
# saque = float(input("Valor do saque: "))
# if saque > conta["saldo"]:
#    print("Saldo insuficiente")
# else:
#    conta["saldo"] -= saque
#    print(conta)
